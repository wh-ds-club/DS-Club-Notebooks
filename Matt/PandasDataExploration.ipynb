# %%
import pandas as pd
pd.options.display.max_columns = None
df = pd.read_csv('data/Nutrition__Physical_Activity__and_Obesity_-_Behavioral_Risk_Factor_Surveillance_System.csv')
df.head()
# Out:
#    YearStart  YearEnd LocationAbbr LocationDesc  \
# 0       2011     2011           AL      Alabama
# 1       2011     2011           AL      Alabama
# 2       2011     2011           AL      Alabama
# 3       2011     2011           AL      Alabama
# 4       2011     2011           AL      Alabama
#
#                                    Datasource                    Class  \
# 0  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 1  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 2  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 3  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 4  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
#
#                      Topic                                           Question  \
# 0  Obesity / Weight Status  Percent of adults aged 18 years and older who ...
# 1  Obesity / Weight Status  Percent of adults aged 18 years and older who ...
# ...

# %%
df.count()
# Out:
# YearStart                     53392
# YearEnd                       53392
# LocationAbbr                  53392
# LocationDesc                  53392
# Datasource                    53392
# Class                         53392
# Topic                         53392
# Question                      53392
# Data_Value_Unit                   0
# Data_Value_Type               53392
# Data_Value                    48346
# Data_Value_Alt                48346
# Data_Value_Footnote_Symbol     5046
# Data_Value_Footnote            5046
# Low_Confidence_Limit          48346
# High_Confidence_Limit         48346
# Sample_Size                   48346
# Total                          1907
# Age(years)                    11438
# Education                      7628
# Gender                         3814
# Income                        13349
# Race/Ethnicity                15256
# GeoLocation                   52384
# ClassID                       53392
# TopicID                       53392
# ...

# %%
df.columns = [x.replace('(years)', '').upper() for x in df.columns]
df.count()
# Out:
# YEARSTART                     53392
# YEAREND                       53392
# LOCATIONABBR                  53392
# LOCATIONDESC                  53392
# DATASOURCE                    53392
# CLASS                         53392
# TOPIC                         53392
# QUESTION                      53392
# DATA_VALUE_UNIT                   0
# DATA_VALUE_TYPE               53392
# DATA_VALUE                    48346
# DATA_VALUE_ALT                48346
# DATA_VALUE_FOOTNOTE_SYMBOL     5046
# DATA_VALUE_FOOTNOTE            5046
# LOW_CONFIDENCE_LIMIT          48346
# HIGH_CONFIDENCE_LIMIT         48346
# SAMPLE_SIZE                   48346
# TOTAL                          1907
# AGE                           11438
# EDUCATION                      7628
# GENDER                         3814
# INCOME                        13349
# RACE/ETHNICITY                15256
# GEOLOCATION                   52384
# CLASSID                       53392
# TOPICID                       53392
# ...

# %%
df.drop(['DATA_VALUE_UNIT','EDUCATION'], axis=1, inplace=True)

# %%
df[df.DATA_VALUE.isnull()]['DATA_VALUE_FOOTNOTE'][23]
# Out:
# 'Data not available because sample size is insufficient.'
